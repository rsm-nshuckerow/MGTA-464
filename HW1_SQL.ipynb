# %%
from sqlalchemy import create_engine, inspect, text
import pandas as pd

## connecting to the rsm-docker database
engine = create_engine('postgresql://jovyan:postgres@127.0.0.1:8765/Northwind')

# %%
customers = pd.read_sql_query('SELECT * FROM customers', con=engine.connect())

# %%
customers.head()
# Out:
#   customerid                         companyname  \
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados
# 2      ANTON             Antonio Moreno Taquería
# 3      AROUT                     Around the Horn
# 4      BERGS                  Berglunds snabbköp
#
#                          address         contactname          contacttitle  \
# 0                  Obere Str. 57        Maria Anders  Sales Representative
# 1  Avda. de la Constitución 2222        Ana Trujillo                 Owner
# 2                Mataderos  2312      Antonio Moreno                 Owner
# 3                120 Hanover Sq.        Thomas Hardy  Sales Representative
# 4                Berguvsvägen  8  Christina Berglund   Order Administrator
#
#           city region postalcode  country           phone             fax
# 0       Berlin   None      12209  Germany     030-0074321     030-0076545
# ...
